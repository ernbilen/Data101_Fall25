# %%
import nltk
from nltk.corpus import gutenberg, stopwords
from collections import Counter

# nltk.download('gutenberg)
# nltk.download('punkt')
# nltk.download('stopwords')

# %%
book_list = ['melville-moby_dick.txt','shakespeare-hamlet.txt',\
             'shakespeare-macbeth.txt','austen-emma.txt','bible-kjv.txt',\
            'bryant-stories.txt','chesterton-brown.txt']

# %%
stop_words = set(stopwords.words('english'))

# %%
# the following line is the way to read books from nltk.corpus gutenberg
# gutenberg.words('melville-moby_dick.txt')
# Out:
# ['[', 'Moby', 'Dick', 'by', 'Herman', 'Melville', ...]

# %%
# loop over book_list, get rid of stopwords, make everything lowercase,
# get rid of punctuation, return the top 10 most frequent words in each book
myfilter = ['said','one','upon'] # custom filter

# loop over book list and get top 10 most common words in each book
for book in book_list:
    print('Now reading:', book)

    words = gutenberg.words(book) # this reads the book from gutenberg

    # make everything lowercase, store in tokens list
    tokens = []
    for w in words:
        tokens.append(w.lower())

    # get rid of stopwords and punctuation
    clean_tokens = []
    for w in tokens:
        # only if your word contains non-numeric and non-punctuation characters and
        # your word is not in the stop_words list, only then your word gets appended
        # to clean_tokens
        if w.isalpha() and w not in stop_words and w not in myfilter:
            clean_tokens.append(w)

    freq = Counter(clean_tokens)

    print(freq.most_common(10)) # prints the top 10 most common words in clean_tokens
# Out:
# Now reading: melville-moby_dick.txt
# [('whale', 1226), ('like', 647), ('man', 527), ('ship', 518), ('ahab', 511), ('ye', 472), ('sea', 455), ('old', 450), ('would', 432), ('though', 384)]
# Now reading: shakespeare-hamlet.txt
# [('ham', 337), ('lord', 211), ('haue', 178), ('king', 172), ('thou', 107), ('shall', 107), ('come', 104), ('let', 104), ('hamlet', 100), ('good', 98)]
# Now reading: shakespeare-macbeth.txt
# [('macb', 137), ('haue', 122), ('thou', 90), ('enter', 81), ('shall', 68), ('macbeth', 62), ('vpon', 62), ('thee', 61), ('macd', 58), ('vs', 57)]
# Now reading: austen-emma.txt
# [('mr', 1153), ('emma', 865), ('could', 837), ('would', 820), ('mrs', 699), ('miss', 599), ('must', 567), ('harriet', 506), ('much', 486), ('weston', 440)]
# Now reading: bible-kjv.txt
# [('shall', 9838), ('unto', 8997), ('lord', 7964), ('thou', 5474), ('thy', 4600), ('god', 4472), ('ye', 3983), ('thee', 3827), ('man', 2735), ('israel', 2575)]
# Now reading: bryant-stories.txt
# [('little', 597), ('came', 191), ('could', 158), ('king', 141), ('went', 122), ('would', 112), ('great', 110), ('day', 107), ('man', 107), ('old', 104)]
# Now reading: chesterton-brown.txt
# [('like', 331), ('man', 308), ('brown', 291), ('father', 231), ('could', 171), ('know', 151), ('little', 146), ('rather', 143), ('would', 135), ('well', 134)]

# %%
# let's try to get total words, number of unique words, average sentence length
import numpy as np

# loop over book list
for book in book_list:
    print('Now reading:', book)

    words = gutenberg.words(book) # this reads the book from gutenberg

    # make everything lowercase, store in tokens list
    tokens = []
    for w in words:
        tokens.append(w.lower())

    # to count non-punctuation characters
    no_punc = []
    for w in tokens:
        if w.isalpha():
            no_punc.append(w)

    # to get the avg sentence length:
    sentences = gutenberg.sents(book)

    sentence_lengths=[]
    for s in sentences:
        sentence_lengths.append(len(s))
    

    print('Total number of words:', len(no_punc))
    print('Total number of unique words:', len(set(no_punc))) # set() gets rid of duplicates
    print('Avg sentence length:', np.round(np.mean(sentence_lengths),2))

    # get rid of stopwords and punctuation
    clean_tokens = []
    for w in tokens:
        # only if your word contains non-numeric and non-punctuation characters and
        # your word is not in the stop_words list, only then your word gets appended
        # to clean_tokens
        if w.isalpha() and w not in stop_words:
            clean_tokens.append(w)
# Out:
# Now reading: melville-moby_dick.txt
# Total number of words: 218361
# Total number of unique words: 16948
# Avg sentence length: 25.93
# Now reading: shakespeare-hamlet.txt
# Total number of words: 30266
# Total number of unique words: 4699
# Avg sentence length: 12.03
# Now reading: shakespeare-macbeth.txt
# Total number of words: 18272
# Total number of unique words: 3447
# Avg sentence length: 12.13
# Now reading: austen-emma.txt
# Total number of words: 161600
# Total number of unique words: 7079
# Avg sentence length: 24.83
# Now reading: bible-kjv.txt
# Total number of words: 791842
# Total number of unique words: 12568
# Avg sentence length: 33.57
# Now reading: bryant-stories.txt
# Total number of words: 46611
# Total number of unique words: 3826
# Avg sentence length: 19.41
# Now reading: chesterton-brown.txt
# Total number of words: 73286
# Total number of unique words: 7737
# Avg sentence length: 22.61

# %%
len(gutenberg.words('melville-moby_dick.txt'))
# Out:
# 260819

# %%
len(set(['book','paper','plane','book']))
# Out:
# 3

# %%
book = gutenberg.words('melville-moby_dick.txt')

# %%
book
# Out:
# ['[', 'Moby', 'Dick', 'by', 'Herman', 'Melville', ...]

# %%
'crazy' in book
# Out:
# True

# %%
tokens = []
for w in book:
    tokens.append(w.lower())

clean_tokens = []
for w in tokens:
    # only if your word contains non-numeric and non-punctuation characters and
    # your word is not in the stop_words list, only then your word gets appended
    # to clean_tokens
    if w.isalpha() and w not in stop_words:
        clean_tokens.append(w)

# %%
for i in range(len(clean_tokens)):
    if clean_tokens[i] == 'crazy':
        print('Found at position: ', i)
# Out:
# Found at position:  2422
# Found at position:  5526
# Found at position:  17098
# Found at position:  17359
# Found at position:  19561
# Found at position:  36152
# Found at position:  39769
# Found at position:  61466
# Found at position:  61819
# Found at position:  82155
# Found at position:  84194
# Found at position:  85634
# Found at position:  99764
# Found at position:  101865

# %%
target = 'crazy' # target word
window = 5 # plus-minus 5 words around the word 'crazy'

# get rid of punctuation
words = []
for w in book:
    if w.isalpha():
        words.append(w)

for i in range(len(words)):
    if words[i] == target: 
        start = max(0, i - window) # ensures that you never negative index
        end = min(len(words),i + window) # ensures that you never go above the total number of words in the book
        context = words[start:end]
        print('Context: ', context)
# Out:
# Context:  ['at', 'some', 'time', 'or', 'other', 'crazy', 'to', 'go', 'to', 'sea']
# Context:  ['placing', 'the', 'candle', 'on', 'a', 'crazy', 'old', 'sea', 'chest', 'that']
# Context:  ['foolish', 'ignorant', 'whim', 'of', 'his', 'crazy', 'widowed', 'mother', 'who', 'died']
# Context:  ['not', 'because', 'of', 'their', 'half', 'crazy', 'conceits', 'on', 'these', 'subjects']
# Context:  ['Queequeg', 'let', 's', 'leave', 'this', 'crazy', 'man', 'But', 'stop', 'tell']
# Context:  ['and', 'thought', 'all', 'evil', 'to', 'crazy', 'Ahab', 'were', 'visibly', 'personified']
# Context:  ['intensity', 'For', 'at', 'such', 'times', 'crazy', 'Ahab', 'the', 'scheming', 'unappeasedly']
# Context:  ['been', 'originally', 'nurtured', 'among', 'the', 'crazy', 'society', 'of', 'Neskyeuna', 'Shakers']
# Context:  ['name', 'was', 'mentioned', 'and', 'the', 'crazy', 'sea', 'that', 'seemed', 'leagued']
# Context:  ['the', 'tiller', 'but', 'with', 'the', 'crazy', 'conceit', 'that', 'the', 'tiller']
# Context:  ['wits', 'but', 'he', 's', 'too', 'crazy', 'witty', 'for', 'my', 'sanity']
# Context:  ['I', 'think', 'Is', 'your', 'Captain', 'crazy', 'whispering', 'Fedallah', 'But', 'Fedallah']
# Context:  ['on', 'board', 'again', 'Peace', 'thou', 'crazy', 'loon', 'cried', 'the', 'Manxman']
# Context:  ['man', 'and', 'a', 'black', 'and', 'crazy', 'but', 'methinks', 'like', 'cures']

# %%
# co-occurances
target = 'crazy'
partner_words=['man','sea', 'Ahab']
window = 5

# create two counters, one for each partner_words
# loop over partner_words list
counts = {} # dictionary
for partner in partner_words:
    counts[partner] = 0 # set counts to 0 initially

# same as before
for i in range(len(words)):
    if words[i] == target: 
        start = max(0, i - window) # ensures that you never negative index
        end = min(len(words),i + window) # ensures that you never go above the total number of words in the book
        context = words[start:end]

        # check if within each context, a partner word appears:
        for partner in partner_words:
            if partner in context: # check if partner word shows up in context
                counts[partner] = counts[partner] + 1 # if so, increase the count by 1

print('Co-occurance counts for target word:', target)
print(counts)
# Out:
# Co-occurance counts for target word: crazy
# {'man': 2, 'sea': 3, 'Ahab': 2}

# %%
import numpy as np

# co-occurance matrix
book = 'melville-moby_dick.txt'
focus_words = ['whale','man','ship','ahab','sea','old','white','death','captain','god']
window = 5

# Make an empty table of zeros
n = len(focus_words) # this should be 10
table = np.zeros((n,n)) # creates a 10 by 10 with 0s at the beginning which will be updated later

# read the book
words = gutenberg.words(book) # this reads the book from gutenberg

# make everything lowercase, store in tokens list
tokens = []
for w in words:
    tokens.append(w.lower())

clean_tokens = []
for w in tokens:
    if w.isalpha() and w not in stop_words:
        clean_tokens.append(w)

# big loop where we count co-occurances:
for i in range(len(clean_tokens)):
    if clean_tokens[i] in focus_words: # note that each word in focus_words is a target word
        start = max(0, i - window) # ensures that you never negative index
        end = min(len(clean_tokens),i + window) # ensures that you never go above the total number of words in the book
        context = clean_tokens[start:end]
        print(context)
        for word in focus_words:
            word in context
# Out:
# ['body', 'brain', 'see', 'ever', 'dusting', 'old', 'lexicons', 'grammars', 'queer', 'handkerchief']
# ['known', 'nations', 'world', 'loved', 'dust', 'old', 'grammars', 'somehow', 'mildly', 'reminded']
# ['hand', 'school', 'others', 'teach', 'name', 'whale', 'fish', 'called', 'tongue', 'leaving']
# ['signification', 'word', 'deliver', 'true', 'hackluyt', 'whale', 'sw', 'dan', 'hval', 'animal']
# ['hvalt', 'arched', 'vaulted', 'webster', 'dictionary', 'whale', 'immediately', 'dut', 'ger', 'wallen']
# ['danish', 'wal', 'dutch', 'hwal', 'swedish', 'whale', 'icelandic', 'whale', 'english', 'baleine']
# ['dutch', 'hwal', 'swedish', 'whale', 'icelandic', 'whale', 'english', 'baleine', 'french', 'ballena']
# ['case', 'least', 'take', 'higgledy', 'piggledy', 'whale', 'statements', 'however', 'authentic', 'extracts']
# ['shall', 'strike', 'unsplinterable', 'glasses', 'extracts', 'god', 'created', 'great', 'whales', 'genesis']
# ['crooked', 'serpent', 'shall', 'slay', 'dragon', 'sea', 'isaiah', 'thing', 'soever', 'besides']
# ['paunch', 'holland', 'plutarch', 'morals', 'indian', 'sea', 'breedeth', 'biggest', 'fishes', 'among']
# ['pliny', 'scarcely', 'proceeded', 'two', 'days', 'sea', 'sunrise', 'great', 'many', 'whales']
# ['sunrise', 'great', 'many', 'whales', 'monsters', 'sea', 'appeared', 'among', 'former', 'one']
# ['mouthed', 'raising', 'waves', 'sides', 'beating', 'sea', 'foam', 'tooke', 'lucian', 'true']
# ['vessel', 'enter', 'dreadful', 'gulf', 'monster', 'whale', 'mouth', 'immediately', 'lost', 'swallowed']
# ['whale', 'mouth', 'immediately', 'lost', 'swallowed', 'sea', 'gudgeon', 'retires', 'great', 'security']
# ['us', 'fly', 'let', 'us', 'fly', 'old', 'nick', 'take', 'leviathan', 'described']
# ['moses', 'life', 'patient', 'job', 'rabelais', 'whale', 'liver', 'two', 'cartloads', 'stowe']
# ['version', 'psalms', 'touching', 'monstrous', 'bulk', 'whale', 'ork', 'received', 'nothing', 'certain']
# ['incredible', 'quantity', 'oil', 'extracted', 'one', 'whale', 'ibid', 'history', 'life', 'death']
# ['one', 'whale', 'ibid', 'history', 'life', 'death', 'sovereignest', 'thing', 'earth', 'parmacetti']
# ['inward', 'bruise', 'king', 'henry', 'like', 'whale', 'hamlet', 'secure', 'skill', 'leach']
# ['bred', 'restless', 'paine', 'like', 'wounded', 'whale', 'shore', 'flies', 'thro', 'maine']
# ['browne', 'sperma', 'ceti', 'sperma', 'ceti', 'whale', 'vide', 'v', 'e', 'like']
# ['commonwealth', 'state', 'latin', 'civitas', 'artificial', 'man', 'opening', 'sentence', 'hobbes', 'leviathan']
# ['swallowed', 'without', 'chewing', 'sprat', 'mouth', 'whale', 'pilgrim', 'progress', 'sea', 'beast']
# ['sprat', 'mouth', 'whale', 'pilgrim', 'progress', 'sea', 'beast', 'leviathan', 'god', 'works']
# ['pilgrim', 'progress', 'sea', 'beast', 'leviathan', 'god', 'works', 'created', 'hugest', 'swim']
# ['land', 'gills', 'draws', 'breath', 'spouts', 'sea', 'ibid', 'mighty', 'whales', 'swim']
# ['sea', 'ibid', 'mighty', 'whales', 'swim', 'sea', 'water', 'sea', 'oil', 'swimming']
# ['mighty', 'whales', 'swim', 'sea', 'water', 'sea', 'oil', 'swimming', 'fulller', 'profane']
# ['mistake', 'way', 'dryden', 'annus', 'mirabilis', 'whale', 'floating', 'stern', 'ship', 'cut']
# ['annus', 'mirabilis', 'whale', 'floating', 'stern', 'ship', 'cut', 'head', 'tow', 'boat']
# ['great', 'deal', 'caution', 'fear', 'run', 'ship', 'upon', 'schouten', 'sixth', 'circumnavigation']
# ['sail', 'elbe', 'wind', 'n', 'e', 'ship', 'called', 'jonas', 'whale', 'say']
# ['n', 'e', 'ship', 'called', 'jonas', 'whale', 'say', 'whale', 'open', 'mouth']
# ['ship', 'called', 'jonas', 'whale', 'say', 'whale', 'open', 'mouth', 'fable', 'frequently']
# ['climb', 'masts', 'see', 'whether', 'see', 'whale', 'first', 'discoverer', 'ducat', 'pains']
# ['first', 'discoverer', 'ducat', 'pains', 'told', 'whale', 'taken', 'near', 'shetland', 'barrel']
# ['belly', 'one', 'harpooneers', 'told', 'caught', 'whale', 'spitzbergen', 'white', 'voyage', 'greenland']
# ['harpooneers', 'told', 'caught', 'whale', 'spitzbergen', 'white', 'voyage', 'greenland', 'harris', 'coll']
# ['anno', 'one', 'eighty', 'feet', 'length', 'whale', 'bone', 'kind', 'came', 'informed']
# ['whether', 'master', 'kill', 'sperma', 'ceti', 'whale', 'could', 'never', 'hear', 'sort']
# ['could', 'never', 'hear', 'sort', 'killed', 'man', 'fierceness', 'swiftness', 'richard', 'strafford']
# ['letter', 'bermudas', 'phil', 'trans', 'whales', 'sea', 'god', 'voice', 'obey', 'n']
# ['bermudas', 'phil', 'trans', 'whales', 'sea', 'god', 'voice', 'obey', 'n', 'e']
# ['say', 'hundred', 'one', 'northward', 'us', 'captain', 'cowley', 'voyage', 'round', 'globe']
# ['cowley', 'voyage', 'round', 'globe', 'breath', 'whale', 'frequendy', 'attended', 'insupportable', 'smell']
# ['tho', 'stuffed', 'hoops', 'armed', 'ribs', 'whale', 'rape', 'lock', 'compare', 'land']
# ['shall', 'find', 'appear', 'contemptible', 'comparison', 'whale', 'doubtless', 'largest', 'animal', 'creation']
# ['saw', 'supposed', 'rock', 'found', 'dead', 'whale', 'asiatics', 'killed', 'towing', 'ashore']
# ['ashore', 'seemed', 'endeavor', 'conceal', 'behind', 'whale', 'order', 'avoid', 'seen', 'us']
# ['venture', 'attack', 'stand', 'great', 'dread', 'sea', 'afraid', 'mention', 'even', 'names']
# ['banks', 'solander', 'voyage', 'iceland', 'spermacetti', 'whale', 'found', 'nantuckois', 'active', 'fierce']
# ['address', 'boldness', 'fishermen', 'thomas', 'jefferson', 'whale', 'memorial', 'french', 'minister', 'pray']
# ['edmund', 'burke', 'reference', 'parliament', 'nantucket', 'whale', 'fishery', 'spain', 'great', 'whale']
# ['nantucket', 'whale', 'fishery', 'spain', 'great', 'whale', 'stranded', 'shores', 'europe', 'edmund']
# ['pirates', 'robbers', 'right', 'royal', 'fish', 'whale', 'sturgeon', 'either', 'thrown', 'ashore']
# ['property', 'king', 'blackstone', 'soon', 'sport', 'death', 'crews', 'repair', 'rodmond', 'unerring']
# ['compare', 'ocean', 'serves', 'high', 'spouted', 'whale', 'air', 'express', 'unwieldy', 'joy']
# ['velocity', 'john', 'hunter', 'account', 'dissection', 'whale', 'small', 'sized', 'one', 'aorta']
# ['whale', 'small', 'sized', 'one', 'aorta', 'whale', 'larger', 'bore', 'main', 'pipe']
# ['inferior', 'impetus', 'velocity', 'blood', 'gushing', 'whale', 'heart', 'paley', 'theology', 'whale']
# ['gushing', 'whale', 'heart', 'paley', 'theology', 'whale', 'mammiferous', 'animal', 'without', 'hind']
# ['whales', 'take', 'till', 'first', 'may', 'sea', 'covered', 'colnett', 'voyage', 'purpose']
# ['colnett', 'voyage', 'purpose', 'extending', 'spermaceti', 'whale', 'fishery', 'free', 'element', 'beneath']
# ['sing', 'finny', 'people', 'king', 'mightier', 'whale', 'vast', 'atlantic', 'fatter', 'fish']
# ['fatter', 'fish', 'flounders', 'round', 'polar', 'sea', 'charles', 'lamb', 'triumph', 'whale']
# ['polar', 'sea', 'charles', 'lamb', 'triumph', 'whale', 'year', 'persons', 'high', 'hill']
# ['spouting', 'sporting', 'one', 'observed', 'pointing', 'sea', 'green', 'pasture', 'children', 'grand']
# ['gateway', 'form', 'gothic', 'arch', 'setting', 'whale', 'jaw', 'bones', 'hawthorne', 'twice']
# ['bespeak', 'monument', 'first', 'love', 'killed', 'whale', 'pacific', 'ocean', 'less', 'forty']
# ['ago', 'ibid', 'sir', 'tis', 'right', 'whale', 'answered', 'tom', 'saw', 'sprout']
# ['introduced', 'stage', 'eckermann', 'conversations', 'goethe', 'god', 'mr', 'chace', 'matter', 'answered']
# ['mr', 'chace', 'matter', 'answered', 'stove', 'whale', 'narrative', 'shipwreck', 'whale', 'ship']
# ['answered', 'stove', 'whale', 'narrative', 'shipwreck', 'whale', 'ship', 'essex', 'nantucket', 'attacked']
# ['stove', 'whale', 'narrative', 'shipwreck', 'whale', 'ship', 'essex', 'nantucket', 'attacked', 'finally']
# ['attacked', 'finally', 'destroyed', 'large', 'sperm', 'whale', 'pacific', 'ocean', 'owen', 'chace']
# ['moonlight', 'pale', 'phospher', 'gleamed', 'wake', 'whale', 'floundered', 'sea', 'elizabeth', 'oakes']
# ['phospher', 'gleamed', 'wake', 'whale', 'floundered', 'sea', 'elizabeth', 'oakes', 'smith', 'quantity']
# ['withdrawn', 'boats', 'engaged', 'capture', 'one', 'whale', 'amounted', 'altogether', 'yards', 'nearly']
# ['nearly', 'six', 'english', 'miles', 'sometimes', 'whale', 'shakes', 'tremendous', 'tail', 'air']
# ['endures', 'fresh', 'attacks', 'infuriated', 'sperm', 'whale', 'rolls', 'rears', 'enormous', 'head']
# ['point', 'view', 'important', 'animal', 'sperm', 'whale', 'entirely', 'neglected', 'excited', 'little']
# ['habitudes', 'thomas', 'beale', 'history', 'sperm', 'whale', 'cachalot', 'sperm', 'whale', 'better']
# ['history', 'sperm', 'whale', 'cachalot', 'sperm', 'whale', 'better', 'armed', 'true', 'whale']
# ['sperm', 'whale', 'better', 'armed', 'true', 'whale', 'greenland', 'right', 'whale', 'possessing']
# ['armed', 'true', 'whale', 'greenland', 'right', 'whale', 'possessing', 'formidable', 'weapon', 'either']
# ['regarded', 'dangerous', 'attack', 'known', 'species', 'whale', 'tribe', 'frederick', 'debell', 'bennett']
# ['sung', 'mast', 'head', 'away', 'demanded', 'captain', 'three', 'points', 'lee', 'bow']
# ['sir', 'mast', 'head', 'ahoy', 'see', 'whale', 'ay', 'ay', 'sir', 'shoal']
# ['ross', 'browne', 'etchings', 'whaling', 'cruize', 'whale', 'ship', 'globe', 'board', 'vessel']
# ['browne', 'etchings', 'whaling', 'cruize', 'whale', 'ship', 'globe', 'board', 'vessel', 'occurred']
# ['globe', 'lay', 'hussey', 'survivors', 'pursued', 'whale', 'wounded', 'parried', 'assault', 'time']
# ['eight', 'nine', 'thousand', 'persons', 'living', 'sea', 'adding', 'largely', 'every', 'year']
# ['senate', 'application', 'erection', 'breakwater', 'nantucket', 'whale', 'fell', 'directly', 'probably', 'killed']
# ['fell', 'directly', 'probably', 'killed', 'moment', 'whale', 'captors', 'whaleman', 'adventures', 'whale']
# ['moment', 'whale', 'captors', 'whaleman', 'adventures', 'whale', 'biography', 'gathered', 'homeward', 'cruise']
# ['brother', 'william', 'comstock', 'another', 'version', 'whale', 'ship', 'globe', 'narrative', 'voyages']
# ['william', 'comstock', 'another', 'version', 'whale', 'ship', 'globe', 'narrative', 'voyages', 'dutch']
# ['main', 'object', 'laid', 'open', 'haunts', 'whale', 'mcculloch', 'commercial', 'dictionary', 'things']
# ['bound', 'forward', 'laying', 'open', 'haunts', 'whale', 'whalemen', 'seem', 'indirectly', 'hit']
# ['passage', 'something', 'unpublished', 'impossible', 'meet', 'whale', 'ship', 'ocean', 'without', 'struck']
# ['something', 'unpublished', 'impossible', 'meet', 'whale', 'ship', 'ocean', 'without', 'struck', 'near']
# ['perhaps', 'told', 'ribs', 'whales', 'tales', 'whale', 'voyager', 'arctic', 'ocean', 'till']
# ['returned', 'pursuit', 'whales', 'whites', 'saw', 'ship', 'bloody', 'possession', 'savages', 'enrolled']
# ['crew', 'newspaper', 'account', 'taking', 'retaking', 'whale', 'ship', 'hobomack', 'generally', 'well']
# ['newspaper', 'account', 'taking', 'retaking', 'whale', 'ship', 'hobomack', 'generally', 'well', 'known']
# ['return', 'ships', 'board', 'departed', 'cruise', 'whale', 'boat', 'suddenly', 'mighty', 'mass']
# ['shot', 'perpendicularly', 'air', 'miriam', 'coffin', 'whale', 'fisherman', 'whale', 'harpooned', 'sure']
# ['air', 'miriam', 'coffin', 'whale', 'fisherman', 'whale', 'harpooned', 'sure', 'bethink', 'would']
# ['saw', 'distended', 'jaws', 'large', 'sperm', 'whale', 'close', 'head', 'boat', 'threatening']
# ['instant', 'destruction', 'stern', 'lives', 'wharton', 'whale', 'killer', 'cheery', 'lads', 'let']
# ['never', 'fail', 'bold', 'harpooneer', 'striking', 'whale', 'nantucket', 'song', 'oh', 'rare']
# ['whale', 'nantucket', 'song', 'oh', 'rare', 'old', 'whale', 'mid', 'storm', 'gale']
# ['nantucket', 'song', 'oh', 'rare', 'old', 'whale', 'mid', 'storm', 'gale', 'ocean']
# ['might', 'might', 'right', 'king', 'boundless', 'sea', 'whale', 'song', 'chapter', 'loomings']
# ['might', 'right', 'king', 'boundless', 'sea', 'whale', 'song', 'chapter', 'loomings', 'call']
# ['hats', 'account', 'high', 'time', 'get', 'sea', 'soon', 'substitute', 'pistol', 'ball']
# ['throws', 'upon', 'sword', 'quietly', 'take', 'ship', 'nothing', 'surprising', 'knew', 'almost']
# ['men', 'plunged', 'deepest', 'reveries', 'stand', 'man', 'legs', 'set', 'feet', 'going']
# ['healthy', 'soul', 'time', 'crazy', 'go', 'sea', 'upon', 'first', 'voyage', 'passenger']
# ['feel', 'mystical', 'vibration', 'first', 'told', 'ship', 'sight', 'land', 'old', 'persians']
# ['first', 'told', 'ship', 'sight', 'land', 'old', 'persians', 'hold', 'sea', 'holy']
# ['sight', 'land', 'old', 'persians', 'hold', 'sea', 'holy', 'greeks', 'give', 'separate']
# ['life', 'key', 'say', 'habit', 'going', 'sea', 'whenever', 'begin', 'grow', 'hazy']
# ['lungs', 'mean', 'inferred', 'ever', 'go', 'sea', 'passenger', 'go', 'passenger', 'must']
# ['unless', 'something', 'besides', 'passengers', 'get', 'sea', 'sick', 'grow', 'quarrelsome', 'sleep']
# ['though', 'something', 'salt', 'ever', 'go', 'sea', 'commodore', 'captain', 'cook', 'abandon']
# ['salt', 'ever', 'go', 'sea', 'commodore', 'captain', 'cook', 'abandon', 'glory', 'distinction']
# ['considerable', 'glory', 'cook', 'sort', 'officer', 'ship', 'board', 'yet', 'somehow', 'never']
# ['reverentially', 'broiled', 'fowl', 'idolatrous', 'dotings', 'old', 'egyptians', 'upon', 'broiled', 'ibis']
# ['huge', 'bake', 'houses', 'pyramids', 'go', 'sea', 'go', 'simple', 'sailor', 'right']
# ['one', 'sense', 'honour', 'particularly', 'come', 'old', 'established', 'family', 'land', 'van']
# ['grin', 'bear', 'even', 'wears', 'time', 'old', 'hunks', 'sea', 'captain', 'orders']
# ['even', 'wears', 'time', 'old', 'hunks', 'sea', 'captain', 'orders', 'get', 'broom']
# ['wears', 'time', 'old', 'hunks', 'sea', 'captain', 'orders', 'get', 'broom', 'sweep']
# ['anything', 'less', 'promptly', 'respectfully', 'obey', 'old', 'hunks', 'particular', 'instance', 'slave']
# ['instance', 'slave', 'tell', 'well', 'however', 'old', 'sea', 'captains', 'may', 'order']
# ['slave', 'tell', 'well', 'however', 'old', 'sea', 'captains', 'may', 'order', 'however']
# ['shoulder', 'blades', 'content', 'always', 'go', 'sea', 'sailor', 'make', 'point', 'paying']
# ['us', 'paid', 'compare', 'urbane', 'activity', 'man', 'receives', 'money', 'really', 'marvellous']
# ['root', 'earthly', 'ills', 'account', 'monied', 'man', 'enter', 'heaven', 'ah', 'cheerfully']
# ['consign', 'perdition', 'finally', 'always', 'go', 'sea', 'sailor', 'wholesome', 'exercise', 'pure']
# ['little', 'suspect', 'wherefore', 'repeatedly', 'smelt', 'sea', 'merchant', 'sailor', 'take', 'head']
# ['among', 'motives', 'overwhelming', 'idea', 'great', 'whale', 'portentous', 'mysterious', 'monster', 'roused']
# ['island', 'bulk', 'undeliverable', 'nameless', 'perils', 'whale', 'attending', 'marvels', 'thousand', 'patagonian']
# ['floated', 'inmost', 'soul', 'endless', 'processions', 'whale', 'mid', 'one', 'grand', 'hooded']
# ['carpet', 'bag', 'stuffed', 'shirt', 'two', 'old', 'carpet', 'bag', 'tucked', 'arm']
# ['horn', 'pacific', 'quitting', 'good', 'city', 'old', 'manhatto', 'duly', 'arrived', 'new']
# ['boisterous', 'something', 'everything', 'connected', 'famous', 'old', 'island', 'amazingly', 'pleased', 'besides']
# ['business', 'whaling', 'though', 'matter', 'poor', 'old', 'nantucket', 'much', 'behind', 'yet']
# ['carthage', 'place', 'first', 'dead', 'american', 'whale', 'stranded', 'else', 'nantucket', 'aboriginal']
# ['looking', 'saw', 'swinging', 'sign', 'door', 'white', 'painting', 'upon', 'faintly', 'representing']
# ['queer', 'sort', 'place', 'gable', 'ended', 'old', 'house', 'one', 'side', 'palsied']
# ['tempestuous', 'wind', 'called', 'euroclydon', 'says', 'old', 'writer', 'whose', 'works', 'possess']
# ['sashless', 'window', 'frost', 'sides', 'wight', 'death', 'glazier', 'true', 'enough', 'thought']
# ['enough', 'thought', 'passage', 'occurred', 'mind', 'old', 'black', 'letter', 'thou', 'reasonest']
# ['keep', 'tempestuous', 'euroclydon', 'euroclydon', 'says', 'old', 'dives', 'red', 'silken', 'wrapper']
# ['found', 'wide', 'low', 'straggling', 'entry', 'old', 'fashioned', 'wainscots', 'reminding', 'one']
# ['wainscots', 'reminding', 'one', 'bulwarks', 'condemned', 'old', 'craft', 'one', 'side', 'hung']
# ['picture', 'truly', 'enough', 'drive', 'nervous', 'man', 'distracted', 'yet', 'sort', 'indefinite']
# ['deceptive', 'idea', 'would', 'dart', 'black', 'sea', 'midnight', 'gale', 'unnatural', 'combat']
# ['horner', 'great', 'hurricane', 'half', 'foundered', 'ship', 'weltering', 'three', 'dismantled', 'masts']
# ['dismantled', 'masts', 'alone', 'visible', 'exasperated', 'whale', 'purposing', 'spring', 'clean', 'craft']
# ['cannibal', 'savage', 'could', 'ever', 'gone', 'death', 'harvesting', 'hacking', 'horrifying', 'implement']
# ['hacking', 'horrifying', 'implement', 'mixed', 'rusty', 'old', 'whaling', 'lances', 'harpoons', 'broken']
# ['flung', 'javan', 'seas', 'run', 'away', 'whale', 'years', 'afterwards', 'slain', 'cape']
# ['like', 'restless', 'needle', 'sojourning', 'body', 'man', 'travelled', 'full', 'forty', 'feet']
# ['yon', 'low', 'arched', 'way', 'cut', 'old', 'times', 'must', 'great', 'central']
# ['duskier', 'place', 'low', 'ponderous', 'beams', 'old', 'wrinkled', 'planks', 'beneath', 'would']
# ['beneath', 'would', 'almost', 'fancy', 'trod', 'old', 'craft', 'cockpits', 'especially', 'howling']
# ['especially', 'howling', 'night', 'corner', 'anchored', 'old', 'ark', 'rocked', 'furiously', 'one']
# ['den', 'bar', 'rude', 'attempt', 'right', 'whale', 'head', 'may', 'stands', 'vast']
# ['may', 'stands', 'vast', 'arched', 'bone', 'whale', 'jaw', 'wide', 'coach', 'might']
# ['within', 'shabby', 'shelves', 'ranged', 'round', 'old', 'decanters', 'bottles', 'flasks', 'jaws']
# ['indeed', 'called', 'bustles', 'little', 'withered', 'old', 'man', 'money', 'dearly', 'sells']
# ['called', 'bustles', 'little', 'withered', 'old', 'man', 'money', 'dearly', 'sells', 'sailors']
# ['money', 'dearly', 'sells', 'sailors', 'deliriums', 'death', 'abominable', 'tumblers', 'pours', 'poison']
# ['night', 'would', 'put', 'half', 'decent', 'man', 'blanket', 'thought', 'right', 'take']
# ['supper', 'supper', 'ready', 'directly', 'sat', 'old', 'wooden', 'settle', 'carved', 'like']
# ['away', 'space', 'legs', 'trying', 'hand', 'ship', 'full', 'sail', 'make', 'much']
# ['morning', 'three', 'years', 'voyage', 'full', 'ship', 'hurrah', 'boys', 'latest', 'news']
# ['boys', 'latest', 'news', 'feegees', 'tramping', 'sea', 'boots', 'heard', 'entry', 'door']
# ['entered', 'wonder', 'made', 'straight', 'wake', 'whale', 'mouth', 'bar', 'wrinkled', 'little']
# ['whale', 'mouth', 'bar', 'wrinkled', 'little', 'old', 'jonah', 'officiating', 'soon', 'poured']
# ['even', 'arrantest', 'topers', 'newly', 'landed', 'sea', 'began', 'capering', 'obstreperously', 'observed']
# ['refrained', 'making', 'much', 'noise', 'rest', 'man', 'interested', 'since', 'sea', 'gods']
# ['noise', 'rest', 'man', 'interested', 'since', 'sea', 'gods', 'ordained', 'soon', 'become']
# ['coffer', 'dam', 'seldom', 'seen', 'brawn', 'man', 'face', 'deeply', 'brown', 'burnt']
# ['face', 'deeply', 'brown', 'burnt', 'making', 'white', 'teeth', 'dazzling', 'contrast', 'deep']
# ['virginia', 'revelry', 'companions', 'mounted', 'height', 'man', 'slipped', 'away', 'unobserved', 'saw']
# ['unobserved', 'saw', 'till', 'became', 'comrade', 'sea', 'minutes', 'however', 'missed', 'shipmates']
# ['plan', 'occurred', 'previous', 'entrance', 'seamen', 'man', 'prefers', 'sleep', 'two', 'bed']
# ['else', 'sailors', 'sleep', 'two', 'bed', 'sea', 'bachelor', 'kings', 'ashore', 'sure']
# ['snug', 'enough', 'saying', 'procured', 'plane', 'old', 'silk', 'handkerchief', 'first', 'dusting']
# ['tending', 'beget', 'uncomfortable', 'feeling', 'towards', 'man', 'design', 'bedfellow', 'sort', 'connexion']
# ['depend', 'upon', 'landlord', 'harpooneer', 'dangerous', 'man', 'pays', 'reg', 'lar', 'rejoinder']
# ['said', 'landlord', 'placing', 'candle', 'crazy', 'old', 'sea', 'chest', 'double', 'duty']
# ['landlord', 'placing', 'candle', 'crazy', 'old', 'sea', 'chest', 'double', 'duty', 'wash']
# ['four', 'walls', 'papered', 'fireboard', 'representing', 'man', 'striking', 'whale', 'things', 'properly']
# ['papered', 'fireboard', 'representing', 'man', 'striking', 'whale', 'things', 'properly', 'belonging', 'room']
# ['inkling', 'truth', 'occurred', 'remembered', 'story', 'white', 'man', 'whaleman', 'falling', 'among']
# ['truth', 'occurred', 'remembered', 'story', 'white', 'man', 'whaleman', 'falling', 'among', 'cannibals']
# ['met', 'similar', 'adventure', 'thought', 'outside', 'man', 'honest', 'sort', 'skin', 'make']
# ['never', 'heard', 'hot', 'sun', 'tanning', 'white', 'man', 'purplish', 'yellow', 'one']
# ['heard', 'hot', 'sun', 'tanning', 'white', 'man', 'purplish', 'yellow', 'one', 'however']
# ['seal', 'skin', 'wallet', 'hair', 'placing', 'old', 'chest', 'middle', 'room', 'took']
# ['back', 'exactly', 'colour', 'three', 'days', 'old', 'congo', 'baby', 'remembering', 'embalmed']
# ['places', 'carefully', 'idol', 'laying', 'bit', 'ship', 'biscuit', 'top', 'applying', 'flame']
# ['tomahawk', 'began', 'flourishing', 'dark', 'landlord', 'god', 'sake', 'peter', 'coffin', 'shouted']
# ['sleep', 'queequeg', 'look', 'sabbee', 'sabbee', 'man', 'sleepe', 'sabbee', 'sabbee', 'plenty']
# ['looking', 'cannibal', 'fuss', 'making', 'thought', 'man', 'human', 'much', 'reason', 'fear']
# ['stop', 'smoking', 'short', 'turn', 'fancy', 'man', 'smoking', 'bed', 'dangerous', 'besides']
# ['shade', 'owing', 'suppose', 'keeping', 'arm', 'sea', 'unmethodically', 'sun', 'shade', 'shirt']
# ['still', 'hugged', 'tightly', 'though', 'naught', 'death', 'part', 'us', 'twain', 'strove']
# ['curiosity', 'getting', 'better', 'breeding', 'nevertheless', 'man', 'like', 'queequeg', 'see', 'every']
# ['though', 'law', 'propriety', 'ever', 'heard', 'man', 'required', 'private', 'putting', 'boots']
# ['scarce', 'good', 'thing', 'pity', 'one', 'man', 'proper', 'person', 'afford', 'stuff']
# ['cheerfully', 'allow', 'spend', 'spent', 'way', 'man', 'anything', 'bountifully', 'laughable', 'sure']
# ['man', 'anything', 'bountifully', 'laughable', 'sure', 'man', 'perhaps', 'think', 'bar', 'room']
# ['mates', 'second', 'mates', 'third', 'mates', 'sea', 'carpenters', 'sea', 'coopers', 'sea']
# ['mates', 'third', 'mates', 'sea', 'carpenters', 'sea', 'coopers', 'sea', 'blacksmiths', 'harpooneers']
# ['mates', 'sea', 'carpenters', 'sea', 'coopers', 'sea', 'blacksmiths', 'harpooneers', 'ship', 'keepers']
# ['sea', 'coopers', 'sea', 'blacksmiths', 'harpooneers', 'ship', 'keepers', 'brown', 'brawny', 'company']
# ['three', 'days', 'landed', 'indian', 'voyage', 'man', 'next', 'looks', 'shades', 'lighter']
# ['whaling', 'small', 'surprise', 'nearly', 'every', 'man', 'maintained', 'profound', 'silence', 'looked']
# ['silence', 'looked', 'embarrassed', 'yes', 'set', 'sea', 'dogs', 'many', 'without', 'slightest']
# ['forests', 'seek', 'drop', 'axe', 'snatch', 'whale', 'lance', 'many', 'green', 'green']
# ['came', 'things', 'would', 'think', 'hours', 'old', 'look', 'chap', 'strutting', 'round']
# ['make', 'distinguished', 'reputation', 'joins', 'great', 'whale', 'fishery', 'see', 'comical', 'things']
# ['things', 'upon', 'reaching', 'seaport', 'bespeaking', 'sea', 'outfit', 'orders', 'bell', 'buttons']
# ['one', 'harpooned', 'dragged', 'hither', 'bottom', 'sea', 'herr', 'alexander', 'perform', 'feat']
# ['gleig', 'forming', 'one', 'boats', 'crews', 'ship', 'eliza', 'towed', 'sight', 'whale']
# ['crews', 'ship', 'eliza', 'towed', 'sight', 'whale', 'shore', 'ground', 'pacific', 'december']
# ['surviving', 'shipmates', 'sacred', 'memory', 'late', 'captain', 'ezekiel', 'hardy', 'bows', 'boat']
# ['hardy', 'bows', 'boat', 'killed', 'sperm', 'whale', 'coast', 'japan', 'august', 'tablet']
# ['sight', 'bleak', 'tablets', 'sympathetically', 'caused', 'old', 'wounds', 'bleed', 'afresh', 'oh']
# ['earth', 'life', 'insurance', 'companies', 'pay', 'death', 'forfeitures', 'upon', 'immortals', 'eternal']
# ['boat', 'make', 'immortal', 'brevet', 'yes', 'death', 'business', 'whaling', 'speechlessly', 'quick']
# ['whaling', 'speechlessly', 'quick', 'chaotic', 'bundling', 'man', 'eternity', 'methinks', 'hugely', 'mistaken']
# ['methinks', 'hugely', 'mistaken', 'matter', 'life', 'death', 'methinks', 'call', 'shadow', 'earth']
# ['chapter', 'pulpit', 'seated', 'long', 'ere', 'man', 'certain', 'venerable', 'robustness', 'entered']
# ['eyeing', 'congregation', 'sufficiently', 'attested', 'fine', 'old', 'man', 'chaplain', 'yes', 'famous']
# ['congregation', 'sufficiently', 'attested', 'fine', 'old', 'man', 'chaplain', 'yes', 'famous', 'father']
# ['father', 'mapple', 'hardy', 'winter', 'healthy', 'old', 'age', 'sort', 'old', 'age']
# ['winter', 'healthy', 'old', 'age', 'sort', 'old', 'age', 'seems', 'merging', 'second']
# ['suit', 'quietly', 'approached', 'pulpit', 'like', 'old', 'fashioned', 'pulpits', 'lofty', 'one']
# ['side', 'ladder', 'like', 'used', 'mounting', 'ship', 'boat', 'sea', 'wife', 'whaling']
# ['like', 'used', 'mounting', 'ship', 'boat', 'sea', 'wife', 'whaling', 'captain', 'provided']
# ['ship', 'boat', 'sea', 'wife', 'whaling', 'captain', 'provided', 'chapel', 'handsome', 'pair']
# ['chapel', 'handsome', 'pair', 'red', 'worsted', 'man', 'ropes', 'ladder', 'nicely', 'headed']
# ['ladder', 'hands', 'grasping', 'ornamental', 'knobs', 'man', 'ropes', 'father', 'mapple', 'cast']
# ['glimpse', 'pulpit', 'escaped', 'however', 'convenient', 'ship', 'joints', 'present', 'instance', 'seemed']
# ['replenished', 'meat', 'wine', 'word', 'faithful', 'man', 'god', 'pulpit', 'see', 'self']
# ['meat', 'wine', 'word', 'faithful', 'man', 'god', 'pulpit', 'see', 'self', 'containing']
# ['feature', 'place', 'borrowed', 'chaplain', 'former', 'sea', 'farings', 'marble', 'cenotaphs', 'either']
# ['adorned', 'large', 'painting', 'representing', 'gallant', 'ship', 'beating', 'terrible', 'storm', 'lee']
# ['shed', 'distinct', 'spot', 'radiance', 'upon', 'ship', 'tossed', 'deck', 'something', 'like']
# ['plank', 'nelson', 'fell', 'ah', 'noble', 'ship', 'angel', 'seemed', 'say', 'beat']
# ['say', 'beat', 'beat', 'thou', 'noble', 'ship', 'bear', 'hardy', 'helm', 'lo']
# ['azure', 'hand', 'pulpit', 'without', 'trace', 'sea', 'taste', 'achieved', 'ladder', 'picture']
# ['ladder', 'picture', 'panelled', 'front', 'likeness', 'ship', 'bluff', 'bows', 'holy', 'bible']
# ['projecting', 'piece', 'scroll', 'work', 'fashioned', 'ship', 'fiddle', 'headed', 'beak', 'could']
# ['pulpit', 'leads', 'world', 'thence', 'storm', 'god', 'quick', 'wrath', 'first', 'descried']
# ['must', 'bear', 'earliest', 'brunt', 'thence', 'god', 'breezes', 'fair', 'foul', 'first']
# ['invoked', 'favourable', 'winds', 'yes', 'world', 'ship', 'passage', 'voyage', 'complete', 'pulpit']
# ['midships', 'midships', 'low', 'rumbling', 'heavy', 'sea', 'boots', 'among', 'benches', 'still']
# ['devout', 'seemed', 'kneeling', 'praying', 'bottom', 'sea', 'ended', 'prolonged', 'solemn', 'tones']
# ['tones', 'like', 'continual', 'tolling', 'bell', 'ship', 'foundering', 'sea', 'fog', 'tones']
# ['continual', 'tolling', 'bell', 'ship', 'foundering', 'sea', 'fog', 'tones', 'commenced', 'reading']
# ['pealing', 'exultation', 'joy', 'ribs', 'terrors', 'whale', 'arched', 'dismal', 'gloom', 'god']
# ['terrors', 'whale', 'arched', 'dismal', 'gloom', 'god', 'sun', 'lit', 'waves', 'rolled']
# ['plunging', 'despair', 'black', 'distress', 'called', 'god', 'could', 'scarce', 'believe', 'mine']
# ['believe', 'mine', 'bowed', 'ear', 'complaints', 'whale', 'confine', 'speed', 'flew', 'relief']
# ['bright', 'lightning', 'shone', 'face', 'deliverer', 'god', 'song', 'ever', 'shall', 'record']
# ['terrible', 'joyful', 'hour', 'give', 'glory', 'god', 'mercy', 'power', 'nearly', 'joined']
# ['last', 'verse', 'first', 'chapter', 'jonah', 'god', 'prepared', 'great', 'fish', 'swallow']
# ['us', 'sound', 'kelpy', 'bottom', 'waters', 'sea', 'weed', 'slime', 'sea', 'us']
# ['bottom', 'waters', 'sea', 'weed', 'slime', 'sea', 'us', 'lesson', 'book', 'jonah']
# ['sinful', 'men', 'lesson', 'pilot', 'living', 'god', 'sinful', 'men', 'lesson', 'us']
# ['son', 'amittai', 'wilful', 'disobedience', 'command', 'god', 'never', 'mind', 'command', 'conveyed']
# ['conveyed', 'found', 'hard', 'command', 'things', 'god', 'would', 'us', 'hard', 'us']
# ['commands', 'us', 'endeavors', 'persuade', 'obey', 'god', 'must', 'disobey', 'disobeying', 'wherein']
# ['disobey', 'disobeying', 'wherein', 'hardness', 'obeying', 'god', 'consists', 'sin', 'disobedience', 'jonah']
# ['sin', 'disobedience', 'jonah', 'still', 'flouts', 'god', 'seeking', 'flee', 'thinks', 'ship']
# ['flouts', 'god', 'seeking', 'flee', 'thinks', 'ship', 'made', 'men', 'carry', 'countries']
# ['ship', 'made', 'men', 'carry', 'countries', 'god', 'reign', 'captains', 'earth', 'skulks']
# ['earth', 'skulks', 'wharves', 'joppa', 'seeks', 'ship', 'bound', 'tarshish', 'lurks', 'perhaps']
# ['ancient', 'days', 'atlantic', 'almost', 'unknown', 'sea', 'joppa', 'modern', 'jaffa', 'shipmates']
# ['jonah', 'sought', 'flee', 'world', 'wide', 'god', 'miserable', 'man', 'oh', 'contemptible']
# ['flee', 'world', 'wide', 'god', 'miserable', 'man', 'oh', 'contemptible', 'worthy', 'scorn']
# ['slouched', 'hat', 'guilty', 'eye', 'skulking', 'god', 'prowling', 'among', 'shipping', 'like']
# ['much', 'dodging', 'search', 'finds', 'tarshish', 'ship', 'receiving', 'last', 'items', 'cargo']
# ['items', 'cargo', 'steps', 'board', 'see', 'captain', 'cabin', 'sailors', 'moment', 'desist']
# ['essays', 'wretched', 'smile', 'strong', 'intuitions', 'man', 'assure', 'mariners', 'innocent', 'gamesome']
# ['lad', 'guess', 'adulterer', 'broke', 'jail', 'old', 'gomorrah', 'belike', 'one', 'missing']
# ['bill', 'stuck', 'spile', 'upon', 'wharf', 'ship', 'moored', 'offering', 'five', 'hundred']
# ['suspicion', 'makes', 'best', 'sailors', 'find', 'man', 'advertised', 'let', 'pass', 'descends']
# ['let', 'pass', 'descends', 'cabin', 'cries', 'captain', 'busy', 'desk', 'hurriedly', 'making']
# ['turns', 'flee', 'rallies', 'seek', 'passage', 'ship', 'tarshish', 'soon', 'sail', 'ye']
# ['ye', 'sir', 'thus', 'far', 'busy', 'captain', 'looked', 'jonah', 'though', 'man']
# ['busy', 'captain', 'looked', 'jonah', 'though', 'man', 'stands', 'sooner', 'hear', 'hollow']
# ['sooner', 'sir', 'soon', 'enough', 'honest', 'man', 'goes', 'passenger', 'ha', 'jonah']
# ['another', 'stab', 'swiftly', 'calls', 'away', 'captain', 'scent', 'sail', 'ye', 'says']
# ['taken', 'context', 'full', 'meaning', 'jonah', 'captain', 'shipmates', 'one', 'whose', 'discernment']
# ['virtue', 'pauper', 'stopped', 'frontiers', 'jonah', 'captain', 'prepares', 'test', 'length', 'jonah']
# ['charges', 'thrice', 'usual', 'sum', 'assented', 'captain', 'knows', 'jonah', 'fugitive', 'time']
# ['purse', 'prudent', 'suspicions', 'still', 'molest', 'captain', 'rings', 'every', 'coin', 'find']
# ['sleep', 'thou', 'lookest', 'like', 'says', 'captain', 'thy', 'room', 'jonah', 'enters']
# ['contains', 'key', 'hearing', 'foolishly', 'fumbling', 'captain', 'laughs', 'lowly', 'mutters', 'something']
# ['gasps', 'contracted', 'hole', 'sunk', 'beneath', 'ship', 'water', 'line', 'jonah', 'feels']
# ['feels', 'heralding', 'presentiment', 'stifling', 'hour', 'whale', 'shall', 'hold', 'smallest', 'bowels']
# ['lamp', 'slightly', 'oscillates', 'jonah', 'room', 'ship', 'heeling', 'towards', 'wharf', 'weight']
# ['turns', 'turns', 'giddy', 'anguish', 'praying', 'god', 'annihilation', 'fit', 'passed', 'last']
# ['woe', 'feels', 'deep', 'stupor', 'steals', 'man', 'bleeds', 'death', 'conscience', 'wound']
# ['deep', 'stupor', 'steals', 'man', 'bleeds', 'death', 'conscience', 'wound', 'naught', 'staunch']
# ['drowning', 'sleep', 'time', 'tide', 'come', 'ship', 'casts', 'cables', 'deserted', 'wharf']
# ['casts', 'cables', 'deserted', 'wharf', 'uncheered', 'ship', 'tarshish', 'careening', 'glides', 'sea']
# ['uncheered', 'ship', 'tarshish', 'careening', 'glides', 'sea', 'ship', 'friends', 'first', 'recorded']
# ['ship', 'tarshish', 'careening', 'glides', 'sea', 'ship', 'friends', 'first', 'recorded', 'smugglers']
# ['first', 'recorded', 'smugglers', 'contraband', 'jonah', 'sea', 'rebels', 'bear', 'wicked', 'burden']
# ['wicked', 'burden', 'dreadful', 'storm', 'comes', 'ship', 'like', 'break', 'boatswain', 'calls']
# ['sleep', 'sees', 'black', 'sky', 'raging', 'sea', 'feels', 'reeling', 'timbers', 'little']
# ['hears', 'heeds', 'far', 'rush', 'mighty', 'whale', 'even', 'open', 'mouth', 'cleaving']
# ['aye', 'shipmates', 'jonah', 'gone', 'sides', 'ship', 'berth', 'cabin', 'taken', 'fast']
# ['deck', 'grasps', 'shroud', 'look', 'upon', 'sea', 'moment', 'sprung', 'upon', 'panther']
# ['bulwarks', 'wave', 'wave', 'thus', 'leaps', 'ship', 'finding', 'speedy', 'vent', 'runs']
# ['nigh', 'drowning', 'yet', 'afloat', 'ever', 'white', 'moon', 'shows', 'affrighted', 'face']
# ['run', 'shouting', 'soul', 'cringing', 'attitudes', 'god', 'fugitive', 'plainly', 'known', 'sailors']
# ['answer', 'forced', 'jonah', 'hard', 'hand', 'god', 'upon', 'hebrew', 'cries', 'fear']
# ['upon', 'hebrew', 'cries', 'fear', 'lord', 'god', 'heaven', 'hath', 'made', 'sea']
# ['lord', 'god', 'heaven', 'hath', 'made', 'sea', 'dry', 'land', 'fear', 'jonah']
# ['well', 'mightest', 'thou', 'fear', 'lord', 'god', 'straightway', 'goes', 'make', 'full']
# ['still', 'pitiful', 'jonah', 'yet', 'supplicating', 'god', 'mercy', 'since', 'well', 'knew']
# ['jonah', 'cries', 'take', 'cast', 'forth', 'sea', 'knew', 'sake', 'great', 'tempest']
# ['mercifully', 'turn', 'seek', 'means', 'save', 'ship', 'vain', 'indignant', 'gale', 'howls']
# ['louder', 'one', 'hand', 'raised', 'invokingly', 'god', 'unreluctantly', 'lay', 'hold', 'jonah']
# ['behold', 'jonah', 'taken', 'anchor', 'dropped', 'sea', 'instantly', 'oily', 'calmness', 'floats']
# ['instantly', 'oily', 'calmness', 'floats', 'east', 'sea', 'still', 'jonah', 'carries', 'gale']
# ['drops', 'seething', 'yawning', 'jaws', 'awaiting', 'whale', 'shoots', 'ivory', 'teeth', 'like']
# ['shoots', 'ivory', 'teeth', 'like', 'many', 'white', 'bolts', 'upon', 'prison', 'jonah']
# ['feels', 'dreadful', 'punishment', 'leaves', 'deliverance', 'god', 'contenting', 'spite', 'pains', 'pangs']
# ['clamorous', 'pardon', 'grateful', 'punishment', 'pleasing', 'god', 'conduct', 'jonah', 'shown', 'eventual']
# ['conduct', 'jonah', 'shown', 'eventual', 'deliverance', 'sea', 'whale', 'shipmates', 'place', 'jonah']
# ['jonah', 'shown', 'eventual', 'deliverance', 'sea', 'whale', 'shipmates', 'place', 'jonah', 'copied']
# ['new', 'power', 'preacher', 'describing', 'jonah', 'sea', 'storm', 'seemed', 'tossed', 'storm']
# ['closed', 'eyes', 'moment', 'seemed', 'communing', 'god', 'leaned', 'towards', 'people', 'bowing']
# ['manliest', 'humility', 'spake', 'words', 'shipmates', 'god', 'laid', 'one', 'hand', 'upon']
# ['lesson', 'jonah', 'teaches', 'pilot', 'living', 'god', 'anointed', 'pilot', 'prophet', 'speaker']
# ['fled', 'mission', 'sought', 'escape', 'duty', 'god', 'taking', 'ship', 'joppa', 'god']
# ['sought', 'escape', 'duty', 'god', 'taking', 'ship', 'joppa', 'god', 'everywhere', 'tarshish']
# ['duty', 'god', 'taking', 'ship', 'joppa', 'god', 'everywhere', 'tarshish', 'never', 'reached']
# ['everywhere', 'tarshish', 'never', 'reached', 'seen', 'god', 'came', 'upon', 'whale', 'swallowed']
# ['reached', 'seen', 'god', 'came', 'upon', 'whale', 'swallowed', 'living', 'gulfs', 'doom']
# ['beyond', 'reach', 'plummet', 'belly', 'hell', 'whale', 'grounded', 'upon', 'ocean', 'utmost']
# ['upon', 'ocean', 'utmost', 'bones', 'even', 'god', 'heard', 'engulphed', 'repenting', 'prophet']
# ['heard', 'engulphed', 'repenting', 'prophet', 'cried', 'god', 'spake', 'unto', 'fish', 'shuddering']
# ['unto', 'fish', 'shuddering', 'cold', 'blackness', 'sea', 'whale', 'came', 'breeching', 'towards']
# ['fish', 'shuddering', 'cold', 'blackness', 'sea', 'whale', 'came', 'breeching', 'towards', 'warm']
# ['bruised', 'beaten', 'ears', 'like', 'two', 'sea', 'shells', 'still', 'multitudinously', 'murmuring']
# ['shipmates', 'lesson', 'woe', 'pilot', 'living', 'god', 'slights', 'woe', 'world', 'charms']
# ['seeks', 'pour', 'oil', 'upon', 'waters', 'god', 'brewed', 'gale', 'woe', 'seeks']
# ['whose', 'strong', 'arms', 'yet', 'support', 'ship', 'base', 'treacherous', 'world', 'gone']
# ['delight', 'acknowledges', 'law', 'lord', 'lord', 'god', 'patriot', 'heaven', 'delight', 'waves']
# ['yet', 'nothing', 'leave', 'eternity', 'thee', 'man', 'live', 'lifetime', 'god', 'said']
# ['eternity', 'thee', 'man', 'live', 'lifetime', 'god', 'said', 'slowly', 'waving', 'benediction']
# ['could', 'altogether', 'maim', 'looked', 'like', 'man', 'never', 'cringed', 'never', 'creditor']
# ['second', 'thoughts', 'something', 'almost', 'sublime', 'man', 'twenty', 'thousand', 'miles', 'home']
# ['conscious', 'living', 'striving', 'soon', 'hear', 'man', 'gives', 'philosopher', 'conclude', 'like']
# ['gives', 'philosopher', 'conclude', 'like', 'dyspeptic', 'old', 'woman', 'must', 'broken', 'digester']
# ['thing', 'much', 'distrusted', 'simple', 'savage', 'old', 'rules', 'would', 'apply', 'supper']
# ['worship', 'thought', 'suppose', 'ishmael', 'magnanimous', 'god', 'heaven', 'earth', 'pagans', 'included']
# ['bit', 'black', 'wood', 'impossible', 'worship', 'god', 'worship', 'god', 'fellow', 'man']
# ['wood', 'impossible', 'worship', 'god', 'worship', 'god', 'fellow', 'man', 'would', 'fellow']
# ['worship', 'god', 'worship', 'god', 'fellow', 'man', 'would', 'fellow', 'man', 'god']
# ['god', 'fellow', 'man', 'would', 'fellow', 'man', 'god', 'queequeg', 'fellow', 'man']
# ['fellow', 'man', 'would', 'fellow', 'man', 'god', 'queequeg', 'fellow', 'man', 'wish']
# ['fellow', 'man', 'god', 'queequeg', 'fellow', 'man', 'wish', 'queequeg', 'would', 'unite']
# ['like', 'bed', 'confidential', 'disclosures', 'friends', 'man', 'wife', 'say', 'open', 'bottom']
# ['wife', 'say', 'open', 'bottom', 'souls', 'old', 'couples', 'often', 'lie', 'chat']
# ['old', 'couples', 'often', 'lie', 'chat', 'old', 'times', 'till', 'nearly', 'morning']
# ['shut', 'order', 'concentrate', 'snugness', 'bed', 'man', 'ever', 'feel', 'identity', 'aright']
# ['nourished', 'untutored', 'youth', 'sag', 'harbor', 'ship', 'visited', 'father', 'bay', 'queequeg']
# ['queequeg', 'sought', 'passage', 'christian', 'lands', 'ship', 'full', 'complement', 'seamen', 'spurned']
# ['canoe', 'paddled', 'distant', 'strait', 'knew', 'ship', 'must', 'pass', 'quitted', 'island']
# ['sat', 'stern', 'paddle', 'low', 'hand', 'ship', 'gliding', 'like', 'flash', 'darted']
# ['go', 'though', 'hacked', 'pieces', 'vain', 'captain', 'threatened', 'throw', 'overboard', 'suspended']
# ['dauntlessness', 'wild', 'desire', 'visit', 'christendom', 'captain', 'last', 'relented', 'told', 'might']
# ['make', 'home', 'fine', 'young', 'savage', 'sea', 'prince', 'wales', 'never', 'saw']
# ['sea', 'prince', 'wales', 'never', 'saw', 'captain', 'cabin', 'put', 'among', 'sailors']
# ['infinitely', 'father', 'heathens', 'arrived', 'last', 'old', 'sag', 'harbor', 'seeing', 'sailors']
# ['world', 'meridians', 'die', 'pagan', 'thus', 'old', 'idolator', 'heart', 'yet', 'lived']
# ['might', 'consider', 'father', 'dead', 'gone', 'old', 'feeble', 'last', 'accounts', 'answered']
# ['touching', 'future', 'movements', 'answered', 'go', 'sea', 'old', 'vocation', 'upon', 'told']
# ['future', 'movements', 'answered', 'go', 'sea', 'old', 'vocation', 'upon', 'told', 'whaling']
# ['whaleman', 'embark', 'resolved', 'accompany', 'island', 'ship', 'aboard', 'vessel', 'get', 'watch']
# ['mysteries', 'whaling', 'though', 'well', 'acquainted', 'sea', 'known', 'merchant', 'seamen', 'story']
# ['ever', 'seen', 'sag', 'harbor', 'owners', 'ship', 'seems', 'lent', 'one', 'carry']
# ['feast', 'held', 'certain', 'grand', 'merchant', 'ship', 'touched', 'rokovoko', 'commander', 'accounts']
# ['accounts', 'stately', 'punctilious', 'gentleman', 'least', 'sea', 'captain', 'commander', 'invited', 'wedding']
# ['stately', 'punctilious', 'gentleman', 'least', 'sea', 'captain', 'commander', 'invited', 'wedding', 'feast']
# ['guests', 'assembled', 'bride', 'bamboo', 'cottage', 'captain', 'marches', 'assigned', 'post', 'honour']
# ['next', 'priest', 'noting', 'ceremony', 'thinking', 'captain', 'ship', 'plain', 'precedence', 'mere']
# ['priest', 'noting', 'ceremony', 'thinking', 'captain', 'ship', 'plain', 'precedence', 'mere', 'island']
# ['island', 'king', 'especially', 'king', 'house', 'captain', 'coolly', 'proceeds', 'wash', 'hands']
# ['wharves', 'side', 'side', 'world', 'wandering', 'whale', 'ships', 'lay', 'silent', 'safely']
# ['heels', 'hoofs', 'turned', 'admire', 'magnanimity', 'sea', 'permit', 'records', 'foam', 'fountain']
# ['two', 'fellow', 'beings', 'companionable', 'though', 'white', 'man', 'anything', 'dignified', 'whitewashed']
# ['fellow', 'beings', 'companionable', 'though', 'white', 'man', 'anything', 'dignified', 'whitewashed', 'negro']
# ['capting', 'devil', 'hallo', 'sir', 'cried', 'captain', 'gaunt', 'rib', 'sea', 'stalking']
# ['sir', 'cried', 'captain', 'gaunt', 'rib', 'sea', 'stalking', 'queequeg', 'thunder', 'mean']
# ['said', 'came', 'near', 'kill', 'e', 'man', 'pointing', 'still', 'shivering', 'greenhorn']
# ['e', 'queequeg', 'kill', 'e', 'big', 'whale', 'look', 'roared', 'captain', 'kill']
# ['e', 'big', 'whale', 'look', 'roared', 'captain', 'kill', 'e', 'cannibal', 'try']
# ['mind', 'eye', 'happened', 'high', 'time', 'captain', 'mind', 'eye', 'prodigious', 'strain']
# ['eyeing', 'boom', 'lower', 'jaw', 'exasperated', 'whale', 'midst', 'consternation', 'queequeg', 'dropped']
# ['hands', 'voted', 'queequeg', 'noble', 'trump', 'captain', 'begged', 'pardon', 'hour', 'clove']
# ['clams', 'sometimes', 'found', 'adhering', 'backs', 'sea', 'turtles', 'extravaganzas', 'show', 'nantucket']
# ['wonder', 'nantucketers', 'born', 'beach', 'take', 'sea', 'livelihood', 'first', 'caught', 'crabs']
# ['last', 'launching', 'navy', 'great', 'ships', 'sea', 'explored', 'watery', 'world', 'put']
# ['flood', 'monstrous', 'mountainous', 'himmalehan', 'salt', 'sea', 'mastodon', 'clothed', 'portentousness', 'unconscious']
# ['malicious', 'assaults', 'thus', 'naked', 'nantucketers', 'sea', 'hermits', 'issuing', 'ant', 'hill']
# ['sea', 'hermits', 'issuing', 'ant', 'hill', 'sea', 'overrun', 'conquered', 'watery', 'world']
# ['two', 'thirds', 'terraqueous', 'globe', 'nantucketer', 'sea', 'owns', 'emperors', 'empires', 'seamen']
# ['even', 'pirates', 'privateers', 'though', 'following', 'sea', 'highwaymen', 'road', 'plunder', 'ships']
# ['deep', 'nantucketer', 'alone', 'resides', 'riots', 'sea', 'alone', 'bible', 'language', 'goes']
# ['though', 'overwhelmed', 'millions', 'china', 'lives', 'sea', 'prairie', 'cocks', 'prairie', 'hides']
# ['warehouse', 'starboard', 'hand', 'till', 'opened', 'white', 'church', 'larboard', 'keeping', 'larboard']
# ['points', 'starboard', 'done', 'ask', 'first', 'man', 'met', 'place', 'crooked', 'directions']
# ['asses', 'ears', 'swung', 'cross', 'trees', 'old', 'top', 'mast', 'planted', 'front']
# ['old', 'top', 'mast', 'planted', 'front', 'old', 'doorway', 'horns', 'cross', 'trees']
# ['horns', 'cross', 'trees', 'sawed', 'side', 'old', 'top', 'mast', 'looked', 'little']
# ['injured', 'eye', 'carrying', 'brisk', 'scolding', 'man', 'purple', 'woollen', 'shirt', 'get']
# ['shirt', 'get', 'along', 'ye', 'said', 'man', 'combing', 'ye', 'come', 'queequeg']
# ['hussey', 'great', 'hurry', 'resume', 'scolding', 'man', 'purple', 'shirt', 'waiting', 'entry']
# ['bigger', 'hazel', 'nuts', 'mixed', 'pounded', 'ship', 'biscuit', 'salted', 'pork', 'cut']
# ['hussey', 'account', 'books', 'bound', 'superior', 'old', 'shark', 'skin', 'fishy', 'flavor']
# ['smoked', 'herring', 'way', 'variety', 'chapter', 'ship', 'bed', 'concocted', 'plans', 'morrow']
# ['consulting', 'yojo', 'name', 'black', 'little', 'god', 'yojo', 'told', 'two', 'three']
# ['say', 'yojo', 'earnestly', 'enjoined', 'selection', 'ship', 'rest', 'wholly', 'inasmuch', 'yojo']
# ['turned', 'chance', 'vessel', 'must', 'immediately', 'ship', 'present', 'irrespective', 'queequeg', 'forgotten']
# ['considerable', 'esteem', 'rather', 'good', 'sort', 'god', 'perhaps', 'meant', 'well', 'enough']
# ['pequod', 'looked', 'around', 'moment', 'decided', 'ship', 'us', 'may', 'seen', 'many']
# ['take', 'word', 'never', 'saw', 'rare', 'old', 'craft', 'rare', 'old', 'pequod']
# ['saw', 'rare', 'old', 'craft', 'rare', 'old', 'pequod', 'ship', 'old', 'school']
# ['old', 'craft', 'rare', 'old', 'pequod', 'ship', 'old', 'school', 'rather', 'small']
# ['craft', 'rare', 'old', 'pequod', 'ship', 'old', 'school', 'rather', 'small', 'anything']
# ['old', 'school', 'rather', 'small', 'anything', 'old', 'fashioned', 'claw', 'footed', 'look']
# ['stained', 'typhoons', 'calms', 'four', 'oceans', 'old', 'hull', 'complexion', 'darkened', 'like']
# ['stood', 'stiffly', 'like', 'spines', 'three', 'old', 'kings', 'cologne', 'ancient', 'decks']
# ['stone', 'canterbury', 'cathedral', 'becket', 'bled', 'old', 'antiquities', 'added', 'new', 'marvellous']
# ['wild', 'business', 'half', 'century', 'followed', 'old', 'captain', 'peleg', 'many', 'years']
# ['business', 'half', 'century', 'followed', 'old', 'captain', 'peleg', 'many', 'years', 'chief']
# ['seaman', 'one', 'principal', 'owners', 'pequod', 'old', 'peleg', 'term', 'chief', 'mateship']
# ['jaw', 'long', 'sharp', 'teeth', 'sperm', 'whale', 'inserted', 'pins', 'fasten', 'old']
# ['sperm', 'whale', 'inserted', 'pins', 'fasten', 'old', 'hempen', 'thews', 'tendons', 'thews']
# ['land', 'wood', 'deftly', 'travelled', 'sheaves', 'sea', 'ivory', 'scorning', 'turnstile', 'wheel']
# ['middle', 'highest', 'part', 'jaws', 'right', 'whale', 'planted', 'broad', 'ends', 'deck']
# ['waved', 'fro', 'like', 'top', 'knot', 'old', 'pottowottamie', 'sachem', 'head', 'triangular']
# ['triangular', 'opening', 'faced', 'towards', 'bows', 'ship', 'insider', 'commanded', 'complete', 'view']
# ['one', 'aspect', 'seemed', 'authority', 'noon', 'ship', 'work', 'suspended', 'enjoying', 'respite']
# ['enjoying', 'respite', 'burden', 'command', 'seated', 'old', 'fashioned', 'oaken', 'chair', 'wriggling']
# ['nothing', 'particular', 'perhaps', 'appearance', 'elderly', 'man', 'saw', 'brown', 'brawny', 'like']
# ['man', 'saw', 'brown', 'brawny', 'like', 'old', 'seamen', 'heavily', 'rolled', 'blue']
# ['together', 'eye', 'wrinkles', 'effectual', 'scowl', 'captain', 'pequod', 'said', 'advancing', 'door']
# ['said', 'advancing', 'door', 'tent', 'supposing', 'captain', 'pequod', 'dost', 'thou', 'want']
# ['proud', 'served', 'marchant', 'ships', 'flukes', 'man', 'makes', 'thee', 'want', 'go']
# ['thou', 'didst', 'rob', 'thy', 'last', 'captain', 'didst', 'thou', 'dost', 'think']
# ['think', 'murdering', 'officers', 'thou', 'gettest', 'sea', 'protested', 'innocence', 'things', 'saw']
# ['saw', 'mask', 'half', 'humorous', 'innuendoes', 'old', 'seaman', 'insulated', 'quakerish', 'nantucketer']
# ['whaling', 'eh', 'ye', 'clapped', 'eye', 'captain', 'ahab', 'captain', 'ahab', 'sir']
# ['eh', 'ye', 'clapped', 'eye', 'captain', 'ahab', 'captain', 'ahab', 'sir', 'aye']
# ['ye', 'clapped', 'eye', 'captain', 'ahab', 'captain', 'ahab', 'sir', 'aye', 'aye']
# ['clapped', 'eye', 'captain', 'ahab', 'captain', 'ahab', 'sir', 'aye', 'aye', 'thought']
# ['ahab', 'sir', 'aye', 'aye', 'thought', 'captain', 'ahab', 'captain', 'ship', 'mistaken']
# ['sir', 'aye', 'aye', 'thought', 'captain', 'ahab', 'captain', 'ship', 'mistaken', 'thought']
# ['aye', 'aye', 'thought', 'captain', 'ahab', 'captain', 'ship', 'mistaken', 'thought', 'speaking']
# ['aye', 'thought', 'captain', 'ahab', 'captain', 'ship', 'mistaken', 'thought', 'speaking', 'captain']
# ['captain', 'ship', 'mistaken', 'thought', 'speaking', 'captain', 'thou', 'art', 'speaking', 'captain']
# ['speaking', 'captain', 'thou', 'art', 'speaking', 'captain', 'peleg', 'ye', 'speaking', 'young']
# ['captain', 'peleg', 'ye', 'speaking', 'young', 'man', 'belongs', 'captain', 'bildad', 'see']
# ['ye', 'speaking', 'young', 'man', 'belongs', 'captain', 'bildad', 'see', 'pequod', 'fitted']
# ['bind', 'past', 'backing', 'clap', 'eye', 'captain', 'ahab', 'young', 'man', 'thou']
# ['past', 'backing', 'clap', 'eye', 'captain', 'ahab', 'young', 'man', 'thou', 'wilt']
# ['clap', 'eye', 'captain', 'ahab', 'young', 'man', 'thou', 'wilt', 'find', 'one']
# ['leg', 'mean', 'sir', 'one', 'lost', 'whale', 'lost', 'whale', 'young', 'man']
# ['sir', 'one', 'lost', 'whale', 'lost', 'whale', 'young', 'man', 'come', 'nearer']
# ['lost', 'whale', 'lost', 'whale', 'young', 'man', 'come', 'nearer', 'devoured', 'chewed']
# ['could', 'know', 'peculiar', 'ferocity', 'particular', 'whale', 'though', 'indeed', 'might', 'inferred']
# ['fact', 'accident', 'look', 'ye', 'young', 'man', 'thy', 'lungs', 'sort', 'soft']
# ['talk', 'shark', 'bit', 'sure', 'ye', 'sea', 'sure', 'sir', 'said', 'thought']
# ['inclined', 'sir', 'good', 'art', 'thou', 'man', 'pitch', 'harpoon', 'live', 'whale']
# ...
# ['word', 'death', 'knell', 'rings', 'old', 'ahab', 'shakes', 'belfry', 'harpoon', 'toss']
# ['ye', 'see', 'forged', 'iron', 'men', 'white', 'whale', 'blistered', 'fool', 'hand']
# ['see', 'forged', 'iron', 'men', 'white', 'whale', 'blistered', 'fool', 'hand', 'dart']
# ['dive', 'straight', 'slay', 'yet', 'great', 'god', 'one', 'single', 'instant', 'show']
# ['never', 'never', 'wilt', 'thou', 'capture', 'old', 'man', 'jesus', 'name', 'worse']
# ['never', 'wilt', 'thou', 'capture', 'old', 'man', 'jesus', 'name', 'worse', 'devil']
# ['murderous', 'fish', 'till', 'swamps', 'last', 'man', 'shall', 'dragged', 'bottom', 'sea']
# ['last', 'man', 'shall', 'dragged', 'bottom', 'sea', 'shall', 'towed', 'infernal', 'world']
# ['st', 'one', 'another', 'eyes', 'matter', 'whale', 'front', 'thy', 'face', 'palm']
# ['palm', 'hand', 'lipless', 'unfeatured', 'blank', 'ahab', 'ever', 'ahab', 'man', 'whole']
# ['lipless', 'unfeatured', 'blank', 'ahab', 'ever', 'ahab', 'man', 'whole', 'act', 'immutably']
# ['unfeatured', 'blank', 'ahab', 'ever', 'ahab', 'man', 'whole', 'act', 'immutably', 'decreed']
# ['stand', 'round', 'men', 'ye', 'see', 'old', 'man', 'cut', 'stump', 'leaning']
# ['round', 'men', 'ye', 'see', 'old', 'man', 'cut', 'stump', 'leaning', 'shivered']
# ['lance', 'propped', 'lonely', 'foot', 'tis', 'ahab', 'body', 'part', 'ahab', 'soul']
# ['foot', 'tis', 'ahab', 'body', 'part', 'ahab', 'soul', 'centipede', 'moves', 'upon']
# ['crack', 'till', 'ye', 'hear', 'know', 'ahab', 'hawser', 'tows', 'purpose', 'yet']
# ['fire', 'cried', 'stubb', 'mechanical', 'muttered', 'ahab', 'men', 'went', 'forward', 'muttered']
# ['brain', 'solve', 'though', 'dusk', 'descended', 'whale', 'still', 'sight', 'leeward', 'sail']
# ['weapons', 'morrow', 'meantime', 'broken', 'keel', 'ahab', 'wrecked', 'craft', 'carpenter', 'made']
# ['another', 'leg', 'still', 'night', 'slouched', 'ahab', 'stood', 'fixed', 'within', 'scuttle']
# ['dawned', 'fair', 'fresh', 'solitary', 'night', 'man', 'fore', 'mast', 'head', 'relieved']
# ['every', 'spar', 'ye', 'see', 'cried', 'ahab', 'whale', 'yet', 'sight', 'infallible']
# ['spar', 'ye', 'see', 'cried', 'ahab', 'whale', 'yet', 'sight', 'infallible', 'wake']
# ['dawn', 'upon', 'world', 'food', 'thought', 'ahab', 'time', 'think', 'ahab', 'never']
# ['food', 'thought', 'ahab', 'time', 'think', 'ahab', 'never', 'thinks', 'feels', 'feels']
# ['feels', 'feels', 'tingling', 'enough', 'mortal', 'man', 'think', 'audacity', 'god', 'right']
# ['enough', 'mortal', 'man', 'think', 'audacity', 'god', 'right', 'privilege', 'thinking', 'ought']
# ['thought', 'brain', 'calm', 'frozen', 'calm', 'old', 'skull', 'cracks', 'like', 'glass']
# ['shreds', 'split', 'sails', 'lash', 'tossed', 'ship', 'cling', 'vile', 'wind', 'doubt']
# ['stand', 'receive', 'single', 'blow', 'even', 'ahab', 'braver', 'thing', 'nobler', 'thing']
# ['body', 'things', 'exasperate', 'outrage', 'mortal', 'man', 'things', 'bodiless', 'bodiless', 'objects']
# ['veer', 'mark', 'however', 'baser', 'currents', 'sea', 'may', 'turn', 'tack', 'mightiest']
# ['poles', 'trades', 'directly', 'blow', 'good', 'ship', 'trades', 'something', 'like', 'something']
# ['come', 'ye', 'regular', 'look', 'outs', 'man', 'braces', 'steering', 'done', 'wind']
# ['quarter', 'pointed', 'reverse', 'direction', 'braced', 'ship', 'sailed', 'hard', 'upon', 'breeze']
# ['hard', 'upon', 'breeze', 'rechurned', 'cream', 'white', 'wake', 'wind', 'steers', 'open']
# ['hauled', 'main', 'brace', 'upon', 'rail', 'god', 'keep', 'us', 'already', 'bones']
# ['inside', 'wet', 'flesh', 'misdoubt', 'disobey', 'god', 'obeying', 'stand', 'sway', 'cried']
# ['god', 'obeying', 'stand', 'sway', 'cried', 'ahab', 'advancing', 'hempen', 'basket', 'meet']
# ['aye', 'aye', 'sir', 'straightway', 'starbuck', 'ahab', 'bidding', 'ahab', 'swung', 'high']
# ['sir', 'straightway', 'starbuck', 'ahab', 'bidding', 'ahab', 'swung', 'high', 'whole', 'hour']
# ['last', 'three', 'points', 'weather', 'bow', 'ahab', 'descried', 'spout', 'instantly', 'three']
# ['one', 'good', 'round', 'look', 'aloft', 'sea', 'time', 'old', 'old', 'sight']
# ['round', 'look', 'aloft', 'sea', 'time', 'old', 'old', 'sight', 'yet', 'somehow']
# ['look', 'aloft', 'sea', 'time', 'old', 'old', 'sight', 'yet', 'somehow', 'young']
# ['common', 'land', 'palmy', 'palms', 'leeward', 'white', 'whale', 'goes', 'way', 'look']
# ['land', 'palmy', 'palms', 'leeward', 'white', 'whale', 'goes', 'way', 'look', 'windward']
# ['quarter', 'good', 'bye', 'good', 'bye', 'old', 'mast', 'head', 'green', 'aye']
# ['warped', 'cracks', 'green', 'weather', 'stains', 'ahab', 'head', 'difference', 'man', 'old']
# ['weather', 'stains', 'ahab', 'head', 'difference', 'man', 'old', 'age', 'matter', 'aye']
# ['stains', 'ahab', 'head', 'difference', 'man', 'old', 'age', 'matter', 'aye', 'old']
# ['man', 'old', 'age', 'matter', 'aye', 'old', 'mast', 'grow', 'old', 'together']
# ['matter', 'aye', 'old', 'mast', 'grow', 'old', 'together', 'sound', 'hulls', 'though']
# ['old', 'together', 'sound', 'hulls', 'though', 'ship', 'aye', 'minus', 'leg', 'heaven']
# ['pilot', 'yet', 'seen', 'eyes', 'bottom', 'sea', 'supposing', 'descend', 'endless', 'stairs']
# ['direful', 'truth', 'touching', 'thyself', 'parsee', 'ahab', 'thy', 'shot', 'fell', 'short']
# ['head', 'keep', 'good', 'eye', 'upon', 'whale', 'gone', 'talk', 'morrow', 'nay']
# ['gone', 'talk', 'morrow', 'nay', 'night', 'white', 'whale', 'lies', 'tied', 'head']
# ['talk', 'morrow', 'nay', 'night', 'white', 'whale', 'lies', 'tied', 'head', 'tail']
# ['boats', 'lowered', 'standing', 'shallop', 'stern', 'ahab', 'hovered', 'upon', 'point', 'descent']
# ['starbuck', 'sir', 'third', 'time', 'soul', 'ship', 'starts', 'upon', 'voyage', 'starbuck']
# ['billow', 'one', 'crested', 'comb', 'starbuck', 'old', 'shake', 'hands', 'man', 'hands']
# ['comb', 'starbuck', 'old', 'shake', 'hands', 'man', 'hands', 'met', 'eyes', 'fastened']
# ['fastened', 'starbuck', 'tears', 'glue', 'oh', 'captain', 'captain', 'noble', 'heart', 'go']
# ['starbuck', 'tears', 'glue', 'oh', 'captain', 'captain', 'noble', 'heart', 'go', 'go']
# ['heart', 'go', 'go', 'see', 'brave', 'man', 'weeps', 'great', 'agony', 'persuasion']
# ['agony', 'persuasion', 'lower', 'away', 'cried', 'ahab', 'tossing', 'mate', 'arm', 'stand']
# ['window', 'master', 'master', 'come', 'back', 'ahab', 'heard', 'nothing', 'voice', 'high']
# ['voice', 'spake', 'true', 'scarce', 'pushed', 'ship', 'numbers', 'sharks', 'seemingly', 'rising']
# ['boat', 'bites', 'thing', 'uncommonly', 'happening', 'whale', 'boats', 'swarming', 'seas', 'sharks']
# ['first', 'sharks', 'observed', 'pequod', 'since', 'white', 'whale', 'first', 'descried', 'whether']
# ['sharks', 'observed', 'pequod', 'since', 'white', 'whale', 'first', 'descried', 'whether', 'ahab']
# ['white', 'whale', 'first', 'descried', 'whether', 'ahab', 'crew', 'tiger', 'yellow', 'barbarians']
# ['end', 'thing', 'end', 'may', 'oh', 'god', 'shoots', 'leaves', 'deadly', 'calm']
# ['eye', 'upon', 'boats', 'mark', 'well', 'whale', 'ho', 'drive', 'hawk', 'see']
# ['main', 'truck', 'ha', 'soars', 'away', 'old', 'man', 'see', 'st', 'thou']
# ['truck', 'ha', 'soars', 'away', 'old', 'man', 'see', 'st', 'thou', 'sight']
# ['see', 'st', 'thou', 'sight', 'oh', 'ahab', 'shudder', 'shudder', 'boats', 'gone']
# ['mast', 'heads', 'downward', 'pointed', 'arm', 'ahab', 'knew', 'whale', 'sounded', 'intending']
# ['downward', 'pointed', 'arm', 'ahab', 'knew', 'whale', 'sounded', 'intending', 'near', 'next']
# ['vast', 'form', 'shot', 'lengthwise', 'obliquely', 'sea', 'shrouded', 'thin', 'drooping', 'veil']
# ['new', 'milk', 'round', 'marble', 'trunk', 'whale', 'give', 'way', 'cried', 'ahab']
# ['trunk', 'whale', 'give', 'way', 'cried', 'ahab', 'oarsmen', 'boats', 'darted', 'forward']
# ['tiers', 'welded', 'tendons', 'overspreading', 'broad', 'white', 'forehead', 'beneath', 'transparent', 'skin']
# ['side', 'upper', 'part', 'bows', 'leaving', 'ahab', 'almost', 'without', 'scar', 'daggoo']
# ['daggoo', 'queequeg', 'stopping', 'strained', 'planks', 'whale', 'swimming', 'turned', 'showed', 'one']
# ['turns', 'upon', 'turns', 'past', 'night', 'whale', 'reeled', 'involutions', 'lines', 'around']
# ['distended', 'eyes', 'turned', 'full', 'upon', 'old', 'ahab', 'harpoon', 'dropped', 'hand']
# ['eyes', 'turned', 'full', 'upon', 'old', 'ahab', 'harpoon', 'dropped', 'hand', 'befooled']
# ['word', 'second', 'hearse', 'away', 'mates', 'ship', 'boats', 'useless', 'repair', 'ye']
# ['useless', 'repair', 'ye', 'time', 'return', 'ahab', 'enough', 'die', 'men', 'first']
# ['ye', 'men', 'arms', 'legs', 'obey', 'whale', 'gone', 'looked', 'nigh', 'boat']
# ['steadily', 'swimming', 'forward', 'almost', 'passed', 'ship', 'thus', 'far', 'sailing', 'contrary']
# ['intent', 'upon', 'pursuing', 'straight', 'path', 'sea', 'oh', 'ahab', 'cried', 'starbuck']
# ['pursuing', 'straight', 'path', 'sea', 'oh', 'ahab', 'cried', 'starbuck', 'late', 'even']
# ['impelled', 'leeward', 'oars', 'canvas', 'last', 'ahab', 'sliding', 'vessel', 'near', 'plainly']
# ['latent', 'deceitfulness', 'malice', 'whichever', 'true', 'white', 'whale', 'way', 'began', 'abate']
# ['deceitfulness', 'malice', 'whichever', 'true', 'white', 'whale', 'way', 'began', 'abate', 'seemed']
# ['boat', 'rapidly', 'nearing', 'though', 'indeed', 'whale', 'last', 'start', 'long', 'one']
# ['last', 'start', 'long', 'one', 'still', 'ahab', 'glided', 'waves', 'unpitying', 'sharks']
# ['jagged', 'crunched', 'left', 'small', 'splinters', 'sea', 'almost', 'every', 'dip', 'heed']
# ['muttered', 'whether', 'sharks', 'swim', 'feast', 'whale', 'ahab', 'pull', 'aye', 'alive']
# ['whether', 'sharks', 'swim', 'feast', 'whale', 'ahab', 'pull', 'aye', 'alive', 'near']
# ['one', 'side', 'ran', 'ranging', 'along', 'white', 'whale', 'flank', 'seemed', 'strangely']
# ['side', 'ran', 'ranging', 'along', 'white', 'whale', 'flank', 'seemed', 'strangely', 'oblivious']
# ['flank', 'seemed', 'strangely', 'oblivious', 'advance', 'whale', 'sometimes', 'ahab', 'fairly', 'within']
# ['strangely', 'oblivious', 'advance', 'whale', 'sometimes', 'ahab', 'fairly', 'within', 'smoky', 'mountain']
# ['within', 'smoky', 'mountain', 'mist', 'thrown', 'whale', 'spout', 'curled', 'round', 'great']
# ['iron', 'far', 'fiercer', 'curse', 'hated', 'whale', 'steel', 'curse', 'sank', 'socket']
# ['boat', 'elevated', 'part', 'gunwale', 'clung', 'ahab', 'would', 'tossed', 'sea', 'three']
# ['gunwale', 'clung', 'ahab', 'would', 'tossed', 'sea', 'three', 'oarsmen', 'foreknew', 'precise']
# ['wave', 'hurled', 'bodily', 'inboard', 'third', 'man', 'helplessly', 'dropping', 'astern', 'still']
# ['mighty', 'volition', 'ungraduated', 'instantaneous', 'swiftness', 'white', 'whale', 'darted', 'weltering', 'sea']
# ['volition', 'ungraduated', 'instantaneous', 'swiftness', 'white', 'whale', 'darted', 'weltering', 'sea', 'ahab']
# ['swiftness', 'white', 'whale', 'darted', 'weltering', 'sea', 'ahab', 'cried', 'steersman', 'take']
# ['white', 'whale', 'darted', 'weltering', 'sea', 'ahab', 'cried', 'steersman', 'take', 'new']
# ['burst', 'upon', 'hearing', 'tremendous', 'rush', 'sea', 'crashing', 'boat', 'whale', 'wheeled']
# ['tremendous', 'rush', 'sea', 'crashing', 'boat', 'whale', 'wheeled', 'round', 'present', 'blank']
# ['catching', 'sight', 'nearing', 'black', 'hull', 'ship', 'seemingly', 'seeing', 'source', 'persecutions']
# ['jaws', 'amid', 'fiery', 'showers', 'foam', 'ahab', 'staggered', 'hand', 'smote', 'forehead']
# ['may', 'yet', 'grope', 'way', 'night', 'whale', 'ship', 'cried', 'cringing', 'oarsmen']
# ['yet', 'grope', 'way', 'night', 'whale', 'ship', 'cried', 'cringing', 'oarsmen', 'oars']
# ['oars', 'slope', 'downwards', 'thy', 'depths', 'sea', 'ere', 'ever', 'late', 'ahab']
# ['depths', 'sea', 'ere', 'ever', 'late', 'ahab', 'may', 'slide', 'last', 'last']
# ['last', 'time', 'upon', 'mark', 'see', 'ship', 'ship', 'dash', 'men', 'ye']
# ['time', 'upon', 'mark', 'see', 'ship', 'ship', 'dash', 'men', 'ye', 'save']
# ['ship', 'dash', 'men', 'ye', 'save', 'ship', 'oarsmen', 'violently', 'forced', 'boat']
# ['forced', 'boat', 'sledge', 'hammering', 'seas', 'whale', 'smitten', 'bow', 'ends', 'two']
# ['caught', 'sight', 'coming', 'monster', 'soon', 'whale', 'whale', 'helm', 'helm', 'oh']
# ['sight', 'coming', 'monster', 'soon', 'whale', 'whale', 'helm', 'helm', 'oh', 'ye']
# ['prayers', 'life', 'long', 'fidelities', 'oh', 'ahab', 'ahab', 'lo', 'thy', 'work']
# ['life', 'long', 'fidelities', 'oh', 'ahab', 'ahab', 'lo', 'thy', 'work', 'steady']
# ['whose', 'duty', 'tells', 'cannot', 'depart', 'god', 'stand', 'stand', 'stand', 'whoever']
# ['sticks', 'grin', 'thee', 'thou', 'grinning', 'whale', 'ever', 'helped', 'stubb', 'kept']
# ['brushwood', 'grin', 'thee', 'thou', 'grinning', 'whale', 'look', 'ye', 'sun', 'moon']
# ['oh', 'oh', 'oh', 'thou', 'grinning', 'whale', 'plenty', 'gulping', 'soon', 'fly']
# ['plenty', 'gulping', 'soon', 'fly', 'ye', 'ahab', 'shoes', 'jacket', 'let', 'stubb']
# ['stubb', 'die', 'drawers', 'mouldy', 'salted', 'death', 'though', 'cherries', 'cherries', 'cherries']
# ['pay', 'ere', 'coppers', 'come', 'voyage', 'ship', 'bows', 'nearly', 'seamen', 'hung']
# ['employments', 'enchanted', 'eyes', 'intent', 'upon', 'whale', 'side', 'side', 'strangely', 'vibrating']
# ['malice', 'whole', 'aspect', 'spite', 'mortal', 'man', 'could', 'solid', 'white', 'buttress']
# ['spite', 'mortal', 'man', 'could', 'solid', 'white', 'buttress', 'forehead', 'smote', 'ship']
# ['solid', 'white', 'buttress', 'forehead', 'smote', 'ship', 'starboard', 'bow', 'till', 'men']
# ['waters', 'pour', 'mountain', 'torrents', 'flume', 'ship', 'hearse', 'second', 'hearse', 'cried']
# ['ship', 'hearse', 'second', 'hearse', 'cried', 'ahab', 'boat', 'wood', 'could', 'american']
# ['could', 'american', 'diving', 'beneath', 'settling', 'ship', 'whale', 'ran', 'quivering', 'along']
# ['american', 'diving', 'beneath', 'settling', 'ship', 'whale', 'ran', 'quivering', 'along', 'keel']
# ['surface', 'far', 'bow', 'within', 'yards', 'ahab', 'boat', 'time', 'lay', 'quiescent']
# ['spires', 'mine', 'thou', 'uncracked', 'keel', 'god', 'bullied', 'hull', 'thou', 'firm']
# ['haughty', 'helm', 'pole', 'pointed', 'prow', 'death', 'glorious', 'ship', 'must', 'ye']
# ['pole', 'pointed', 'prow', 'death', 'glorious', 'ship', 'must', 'ye', 'perish', 'without']
# ['meanest', 'shipwrecked', 'captains', 'oh', 'lonely', 'death', 'lonely', 'life', 'oh', 'feel']
# ['life', 'top', 'one', 'piled', 'comber', 'death', 'towards', 'thee', 'roll', 'thou']
# ['thee', 'roll', 'thou', 'destroying', 'unconquering', 'whale', 'last', 'grapple', 'thee', 'hell']
# ['though', 'tied', 'thee', 'thou', 'damned', 'whale', 'thus', 'give', 'spear', 'harpoon']
# ['give', 'spear', 'harpoon', 'darted', 'stricken', 'whale', 'flew', 'forward', 'igniting', 'velocity']
# ['line', 'ran', 'grooves', 'ran', 'foul', 'ahab', 'stooped', 'clear', 'clear', 'flying']
# ['empty', 'tub', 'knocked', 'oarsman', 'smiting', 'sea', 'disappeared', 'depths', 'instant', 'tranced']
# ['boat', 'crew', 'stood', 'still', 'turned', 'ship', 'great', 'god', 'ship', 'soon']
# ['stood', 'still', 'turned', 'ship', 'great', 'god', 'ship', 'soon', 'dim', 'bewildering']
# ['still', 'turned', 'ship', 'great', 'god', 'ship', 'soon', 'dim', 'bewildering', 'mediums']
# ['harpooneers', 'still', 'maintained', 'sinking', 'lookouts', 'sea', 'concentric', 'circles', 'seized', 'lone']
# ['etherial', 'thrill', 'submerged', 'savage', 'beneath', 'death', 'gasp', 'kept', 'hammer', 'frozen']
# ['whole', 'captive', 'form', 'folded', 'flag', 'ahab', 'went', 'ship', 'like', 'satan']
# ['form', 'folded', 'flag', 'ahab', 'went', 'ship', 'like', 'satan', 'would', 'sink']
# ['screaming', 'yet', 'yawning', 'gulf', 'sullen', 'white', 'surf', 'beat', 'steep', 'sides']
# ['steep', 'sides', 'collapsed', 'great', 'shroud', 'sea', 'rolled', 'rolled', 'five', 'thousand']
# ['disappearance', 'fates', 'ordained', 'take', 'place', 'ahab', 'bowsman', 'bowsman', 'assumed', 'vacant']
# ['full', 'sight', 'halfspent', 'suction', 'sunk', 'ship', 'reached', 'slowly', 'drawn', 'towards']
# ['coffin', 'life', 'buoy', 'shot', 'lengthwise', 'sea', 'fell', 'floated', 'side', 'buoyed']
# ['sharks', 'glided', 'padlocks', 'mouths', 'savage', 'sea', 'hawks', 'sailed', 'sheathed', 'beaks']
